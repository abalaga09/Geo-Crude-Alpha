# %% [markdown]
# <a href="https://colab.research.google.com/github/abalaga09/Geo-Crude-Alpha/blob/feat-QR/Another_copy_of_Making_the_Most_of_your_Colab_Subscription.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Making the Most of your Colab Subscription

# %% [markdown]
# ## Faster GPUs
#
# Users who have purchased one of Colab's paid plans have access to faster GPUs and more memory. You can upgrade your notebook's GPU settings in `Runtime > Change runtime type` in the menu to select from several accelerator options, subject to availability.
#
# The free of charge version of Colab grants access to Nvidia's T4 GPUs subject to quota restrictions and availability.
#
# You can see what GPU you've been assigned at any time by executing the following cell. If the execution result of running the code cell below is "Not connected to a GPU", you can change the runtime by going to `Runtime > Change runtime type` in the menu to enable a GPU accelerator, and then re-execute the code cell.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# %% [markdown]
# In order to use a GPU with your notebook, select the `Runtime > Change runtime type` menu, and then set the hardware accelerator to the desired option.

# %% [markdown]
# ## More memory
#
# Users who have purchased one of Colab's paid plans have access to high-memory VMs when they are available. More powerful GPUs are always offered with high-memory VMs.
#
#
#
# You can see how much memory you have available at any time by running the following code cell. If the execution result of running the code cell below is "Not using a high-RAM runtime", then you can enable a high-RAM runtime via `Runtime > Change runtime type` in the menu. Then select High-RAM in the Runtime shape toggle button. After, re-execute the code cell.

# %%
import psutil

ram_gb = psutil.virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')

# %% [markdown]
# ## Longer runtimes
#
# All Colab runtimes are reset after some period of time (which is faster if the runtime isn't executing code). Colab Pro and Pro+ users have access to longer runtimes than those who use Colab free of charge.
#
# ## Background execution
#
# Colab Pro+ users have access to background execution, where notebooks will continue executing even after you've closed a browser tab. This is always enabled in Pro+ runtimes as long as you have compute units available.

# %% [markdown]
# ## Relaxing resource limits in Colab Pro
#
# Your resources are not unlimited in Colab. To make the most of Colab, avoid using resources when you don't need them. For example, only use a GPU when required and close Colab tabs when finished.
#
#
#
# If you encounter limitations, you can relax those limitations by purchasing more compute units via Pay As You Go. Anyone can purchase compute units via [Pay As You Go](https://colab.research.google.com/signup); no subscription is required.

# %% [markdown]
# ## Send us feedback!
#
# If you have any feedback for us, please let us know. The best way to send feedback is by using the Help > 'Send feedback...' menu. If you encounter usage limits in Colab Pro consider subscribing to Pro+.
#
# If you encounter errors or other issues with billing (payments) for Colab Pro, Pro+, or Pay As You Go, please email [colab-billing@google.com](mailto:colab-billing@google.com).

# %% [markdown]
# ## More Resources
#
# ### Working with Notebooks in Colab
# - [Overview of Colab](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <a name="working-with-data"></a>
# ### Working with Data
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# ### Machine Learning Crash Course
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TPUs in Colab](/notebooks/tpu.ipynb)

# %% [markdown]
# <a name="machine-learning-examples"></a>
#
# ## Machine Learning Examples
#
# To see end-to-end examples of the interactive machine learning analyses that Colab makes possible, check out these tutorials using models from [TensorFlow Hub](https://tfhub.dev).
#
# A few featured examples:
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
# !git config --global user.name "abalaga09"
# !git config --global user.email "balagaainesh@gmail.com"
# !git config --global user.password "SaiRam!!69"

# %%
token = 'oilgas321'
username = 'abalaga09'
repo = 'Geo-Crude-Alpha'

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'Geo-Crude-Alpha'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 18 (delta 5), reused 10 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 8.47 KiB | 8.47 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd {repo}
# Out:
# /content/Geo-Crude-Alpha

# %%
# !git branch -a
# Out:
# * main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/feat-Data
#   remotes/origin/feat-QR
#   remotes/origin/feat-QT
#   remotes/origin/main
#   remotes/origin/patch-1
#   remotes/origin/patch-2

# %%
# !git checkout feat-QR
# Out:
# Branch 'feat-QR' set up to track remote branch 'feat-QR' from 'origin'.
# Switched to a new branch 'feat-QR'

# %%
#12 years worth of historical data for WTI Crude Oil
import numpy as np
import pandas as pd
import yfinance as yf

tickers = ['CL=F']

ticker_price = yf.download(tickers, start='2013-01-01')

ticker_price
# Out:
# /tmp/ipython-input-10-3608553103.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   ticker_price = yf.download(tickers, start='2013-01-01')
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open  Volume
# Ticker           CL=F       CL=F       CL=F       CL=F    CL=F
# Date
# 2013-01-02  93.120003  93.870003  91.559998  91.779999  203865
# 2013-01-03  92.919998  93.300003  92.489998  92.910004  189812
# 2013-01-04  93.089996  93.209999  91.519997  92.860001  210747
# 2013-01-07  93.190002  93.349998  92.419998  93.209999  166292
# 2013-01-08  93.150002  93.800003  92.669998  93.320000  195867
# ...               ...        ...        ...        ...     ...
# 2025-06-18  75.139999  76.070000  72.940002  75.610001       0
# 2025-06-20  74.930000  77.580002  74.300003  74.599998  678377
# 2025-06-23  68.510002  78.400002  66.599998  78.000000  728868
# ...

# %%
closing_price = ticker_price['Close']

#convert close price to returns
ret = closing_price.pct_change()

ret['Volume'] = ticker_price['Volume']
ret.columns = ['Returns', 'Volume']
ret
# Out:
#              Returns  Volume
# Date
# 2013-01-02       NaN  203865
# 2013-01-03 -0.002148  189812
# 2013-01-04  0.001830  210747
# 2013-01-07  0.001074  166292
# 2013-01-08 -0.000429  195867
# ...              ...     ...
# 2025-06-18  0.004009       0
# 2025-06-20 -0.002795  678377
# 2025-06-23 -0.085680  728868
# 2025-06-24 -0.060429  728868
# 2025-06-25  0.013516  122555
#
# [3138 rows x 2 columns]

# %%
ret = ret.reset_index()  # Moves Date index into a column
ret['Date'] = pd.to_datetime(ret['Date'])  # Now this will work

# %%
#oil_csv = ret.to_csv('crude_oil.csv')
ret.columns
# Out:
# Index(['Returns', 'Volume'], dtype='object')

# %%
#implement time series data analysis
ret['Returns'].plot()
ret_cleaned = ret['Returns'].dropna()
ret_cleaned
# Out:
# Date
# 2013-01-03   -0.002148
# 2013-01-04    0.001830
# 2013-01-07    0.001074
# 2013-01-08   -0.000429
# 2013-01-09   -0.000537
#                 ...
# 2025-06-18    0.004009
# 2025-06-20   -0.002795
# 2025-06-23   -0.085680
# 2025-06-24   -0.060429
# 2025-06-25    0.013516
# Name: Returns, Length: 3137, dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

# %%
decomp = seasonal_decompose(ret_cleaned, model='additive',period=365)
decomp.plot()
plt.show()

# %%
from statsmodels.tsa.seasonal import STL
stl = STL(ret_cleaned, period= 365)
res = stl.fit()
res.plot()
plt.suptitle('STL Decomposition')
plt.tight_layout()
plt.show()

# %%
# !git add --all

# %%
# !git switch feat-QR
# Out:
# Already on 'feat-QR'
# Your branch is up to date with 'origin/feat-QR'.

# %%
# !git status
# Out:
# On branch feat-QR
# Your branch is up to date with 'origin/feat-QR'.
#
# nothing to commit, working tree clean

# %%
# !git push https://<username>:<token>@github.com/abalaga09/Geo-Crude-Alpha.git feat-QR
# Out:
# /bin/bash: line 1: username: No such file or directory

# %%
# !git push https://github.com/abalaga09/Geo-Crude-Alpha.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model = SARIMAX(ret['CL=F'])
results = model.fit()
print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                   CL=F   No. Observations:                 3136
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                4239.686
# Date:                Tue, 24 Jun 2025   AIC                          -8475.372
# Time:                        04:45:58   BIC                          -8463.271
# Sample:                             0   HQIC                         -8471.029
#                                - 3136
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2772      0.002    112.224      0.000       0.272       0.282
# sigma2         0.0039   3.35e-06   1169.437      0.000       0.004       0.004
# ...
# Ljung-Box (L1) (Q):                   8.71   Jarque-Bera (JB):         411812680.43
# ...

# %%
results.plot_diagnostics(figsize=(12,8))
plt.show()

# %%
#signal construction

time_series_risk = SARIMA(ret['Date'])
if time_series_risk == True:
  ret['time_signal'] == 1
else:
  ret['time_signal'] == 0

ret
columns = ['Date', 'Returns','Volume', 'original_signal','time_signal']

#backtest
pnl = 0
capital = 50000
ret.iterrows()

# %%
Quant Commodities Project(Github)
Quant_strat_1: Time Series Strategy
Quant_strat_2: Sentiment Analysis Strategy
Quant_strat_3: Quantamental Strategy(Combination of Quantative finance and Fundamental analysis)
Quant_strat_4: Machine Learning/Technical Indicator Strategy

weight this stuff depending on the drawdown, sharpe_ratio, equity_curve, volatility, over_all portfolio

deploy into some form of a live trading environment (paper trade)

Added Bonus:Implementing margin requirements (Quant Risk Analyst)-VAR Model
Intra-day margin requirements
Overnight margin requirements
Maintain margin requirements

Relational Database store these trades - trading journal
